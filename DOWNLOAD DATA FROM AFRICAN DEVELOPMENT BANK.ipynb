# %%
import pandas as pd

from dbnomics import fetch_series, fetch_series_by_api_link

# %%
indicators = ["NY.GDP.MKTP.CN",'FM.LBL.MONY.CN','FM.LBL.MQMY.CN','GC.REV.TAX.GD.CN','GC.REV.TOTL.GD.ZS','GC.REV.TOTL.GD.CN','GC.XPN.TOTL.GD.ZS','GC.XPN.TOTL.GD.CN','GC.BAL.CASH.GD.ZS','GC.BAL.CASH.GD.CN','SL.TLF.15UP.UEM','LM.POP.EPP.TOT']

# %%
df = fetch_series("AFDB", "bbkawjf", dimensions={"indicator": indicators}, max_nb_series=10000)
df.head()
# Out:
# C:\Users\Richard Lu\anaconda3\Lib\site-packages\dbnomics\__init__.py:336: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(objs=dataframes, sort=False)
#   @frequency provider_code dataset_code                  dataset_name  \
# 0     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 1     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 2     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 3     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 4     annual          AFDB      bbkawjf  AFDB Socio Economic Database
#
#           series_code                   series_name original_period  \
# 0  FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            1995
# ...

# %%
fetch_series?

# %%
df.to_excel('experiment.xlsx')
